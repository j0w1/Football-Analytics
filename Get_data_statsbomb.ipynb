# %%
# import library and get the list of available functions.
import warnings
warnings.filterwarnings('ignore')
from statsbombpy import sb

functions = [func for func in dir(sb) if callable(getattr(sb, func))]
functions
# Out:
# ['Pool',
#  'Union',
#  '_360_frames',
#  'competition_events',
#  'competition_frames',
#  'competitions',
#  'events',
#  'filter_and_group_events',
#  'frames',
#  'lineups',
#  'matches',
#  'merge_events_and_frames',
#  'partial',
#  'player_match_stats',
#  'player_season_stats',
#  'reduce_events',
#  'team_season_stats']

# %% [markdown]
# ## Competitions:

# %%
#Take a look over all competitions provided
sb.competitions()
# Out:
#     competition_id  season_id   country_name    competition_name  \
# 0                9         27        Germany       1. Bundesliga
# 1               16          4         Europe    Champions League
# 2               16          1         Europe    Champions League
# 3               16          2         Europe    Champions League
# 4               16         27         Europe    Champions League
# ..             ...        ...            ...                 ...
# 61              12         86          Italy             Serie A
# 62              55         43         Europe           UEFA Euro
# 63              35         75         Europe  UEFA Europa League
# 64              53        106         Europe   UEFA Women's Euro
# 65              72         30  International   Women's World Cup
#
#    competition_gender  competition_youth  competition_international  \
# 0                male              False                      False
# ...

# %% [markdown]
# ## Matches:

# %%
#Matches for the season selected
sb.matches(competition_id=11 , season_id=4)
# Out:
#     match_id  match_date      kick_off      competition     season  \
# 0      15978  2018-09-15  16:15:00.000  Spain - La Liga  2018/2019
# 1      15998  2018-09-26  20:00:00.000  Spain - La Liga  2018/2019
# 2      16029  2018-10-20  20:45:00.000  Spain - La Liga  2018/2019
# 3      16073  2018-11-24  20:45:00.000  Spain - La Liga  2018/2019
# 4      16086  2018-12-08  20:45:00.000  Spain - La Liga  2018/2019
# 5      16190  2019-02-23  16:15:00.000  Spain - La Liga  2018/2019
# 6      16109  2018-12-22  18:30:00.000  Spain - La Liga  2018/2019
# 7      16120  2019-01-06  20:45:00.000  Spain - La Liga  2018/2019
# 8      16182  2019-02-16  20:45:00.000  Spain - La Liga  2018/2019
# 9      16215  2019-03-17  20:45:00.000  Spain - La Liga  2018/2019
# 10     16173  2019-02-10  20:45:00.000  Spain - La Liga  2018/2019
# 11     16265  2019-04-20  20:45:00.000  Spain - La Liga  2018/2019
# 12     15946  2018-08-18  22:15:00.000  Spain - La Liga  2018/2019
# ...

# %% [markdown]
# ## Match events:

# %%
#Event data for the match selected
sb.events(match_id=69212)
# Out:
#      bad_behaviour_card ball_receipt_outcome ball_recovery_recovery_failure  \
# 0                   NaN                  NaN                            NaN
# 1                   NaN                  NaN                            NaN
# 2                   NaN                  NaN                            NaN
# 3                   NaN                  NaN                            NaN
# 4                   NaN                  NaN                            NaN
# ...                 ...                  ...                            ...
# 3635                NaN                  NaN                            NaN
# 3636                NaN                  NaN                            NaN
# 3637                NaN                  NaN                            NaN
# 3638                NaN                  NaN                            NaN
# 3639                NaN                  NaN                            NaN
#
# ...

# %% [markdown]
# ## Export to csv:

# %%
events.to_csv(r'Barca_vs_Atleti_08_09.csv',encoding='UTF-8', sep=';',index=False,decimal=',')
