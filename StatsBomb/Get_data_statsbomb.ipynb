# %%
from statsbombpy import sb

# %%
# import library and get the list of available functions.
from statsbombpy import sb

functions = [func for func in dir(sb) if callable(getattr(sb, func))]
functions
# Out:
# ['Pool',
#  'Union',
#  '_360_frames',
#  'competition_events',
#  'competition_frames',
#  'competitions',
#  'events',
#  'filter_and_group_events',
#  'frames',
#  'lineups',
#  'matches',
#  'merge_events_and_frames',
#  'partial',
#  'player_match_stats',
#  'player_season_stats',
#  'reduce_events',
#  'team_season_stats']

# %% [markdown]
# ## Competitions:

# %%
#Take a look over all competitions provided
sb.competitions()
# Out:
# C:\Users\LIDIA VICENTE BENITO\anaconda3\lib\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
#     competition_id  season_id              country_name  \
# 0               16          4                    Europe
# 1               16          1                    Europe
# 2               16          2                    Europe
# 3               16         27                    Europe
# 4               16         26                    Europe
# 5               16         25                    Europe
# 6               16         24                    Europe
# 7               16         23                    Europe
# 8               16         22                    Europe
# 9               16         21                    Europe
# 10              16         41                    Europe
# 11              16         39                    Europe
# 12              16         37                    Europe
# ...

# %% [markdown]
# ## Matches:

# %%
sb.matches(competition_id=11 , season_id=4).sort_values('match_date')
# Out:
# C:\Users\LIDIA VICENTE BENITO\anaconda3\lib\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
#     match_id  match_date      kick_off      competition     season  \
# 12     15946  2018-08-18  22:15:00.000  Spain - La Liga  2018/2019
# 32     15956  2018-08-25  22:15:00.000  Spain - La Liga  2018/2019
# 21     15973  2018-09-02  18:30:00.000  Spain - La Liga  2018/2019
# 0      15978  2018-09-15  16:15:00.000  Spain - La Liga  2018/2019
# 28     15986  2018-09-23  20:45:00.000  Spain - La Liga  2018/2019
# 1      15998  2018-09-26  20:00:00.000  Spain - La Liga  2018/2019
# 27     16010  2018-09-29  16:15:00.000  Spain - La Liga  2018/2019
# 30     16023  2018-10-07  20:45:00.000  Spain - La Liga  2018/2019
# 2      16029  2018-10-20  20:45:00.000  Spain - La Liga  2018/2019
# 16     16056  2018-11-11  16:15:00.000  Spain - La Liga  2018/2019
# ...

# %% [markdown]
# ## Match_events:

# %%
events=sb.events(match_id=69212)
# Out:
# C:\Users\LIDIA VICENTE BENITO\anaconda3\lib\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(

# %%
events.head()
# Out:
#   bad_behaviour_card ball_receipt_outcome ball_recovery_recovery_failure  \
# 0                NaN                  NaN                            NaN
# 1                NaN                  NaN                            NaN
# 2                NaN                  NaN                            NaN
# 3                NaN                  NaN                            NaN
# 4                NaN                  NaN                            NaN
#
#   block_offensive carry_end_location clearance_aerial_won clearance_body_part  \
# 0             NaN                NaN                  NaN                 NaN
# 1             NaN                NaN                  NaN                 NaN
# 2             NaN                NaN                  NaN                 NaN
# 3             NaN                NaN                  NaN                 NaN
# 4             NaN                NaN                  NaN                 NaN
#
# ...

# %%
events.columns
# Out:
# Index(['bad_behaviour_card', 'ball_receipt_outcome',
#        'ball_recovery_recovery_failure', 'block_deflection',
#        'carry_end_location', 'clearance_aerial_won', 'clearance_body_part',
#        'clearance_head', 'clearance_left_foot', 'clearance_right_foot',
#        'counterpress', 'dribble_nutmeg', 'dribble_outcome', 'dribble_overrun',
#        'duel_outcome', 'duel_type', 'duration', 'foul_committed_advantage',
#        'foul_committed_card', 'foul_committed_offensive',
#        'foul_committed_type', 'foul_won_advantage', 'foul_won_defensive',
#        'goalkeeper_body_part', 'goalkeeper_end_location', 'goalkeeper_outcome',
#        'goalkeeper_position', 'goalkeeper_technique', 'goalkeeper_type', 'id',
#        'index', 'interception_outcome', 'location', 'match_id', 'minute',
#        'off_camera', 'out', 'pass_aerial_won', 'pass_angle',
#        'pass_assisted_shot_id', 'pass_body_part', 'pass_cross',
#        'pass_cut_back', 'pass_deflected', 'pass_end_location',
# ...

# %% [markdown]
# ## Export to csv:

# %%
events.to_csv(r"C:\Users\LIDIA VICENTE BENITO\Documents\Jowi\DATA SCIENCE\Football\scrapping_futbol\Statsbomb\Datasets\Barca_vs_Atleti_08_09.csv",encoding='UTF-8', sep=';',index=False,decimal=',')
